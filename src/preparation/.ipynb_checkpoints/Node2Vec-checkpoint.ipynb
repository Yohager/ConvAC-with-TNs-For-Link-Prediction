# %%
#调用node2vec库函数测试
import networkx as nx
from node2vec import Node2Vec
from matplotlib import pyplot as plt

# %%
#create a graph
test_graph = nx.fast_gnp_random_graph(n=10,p=0.5) 
nx.draw(test_graph)

# %%
test_graph.edges()
# Out:
# EdgeView([(0, 1), (0, 2), (0, 5), (0, 6), (0, 7), (1, 3), (1, 5), (1, 6), (1, 8), (2, 3), (2, 4), (2, 5), (2, 6), (2, 7), (2, 8), (3, 6), (3, 8), (4, 7), (4, 9), (5, 7), (5, 8), (6, 7), (6, 8), (6, 9), (7, 8)])

# %%
node2vec_testgraph = Node2Vec(test_graph,dimensions=10,walk_length=3,num_walks=20)
# Out:
# Computing transition probabilities: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 1998.62it/s]
# Generating walks (CPU: 1): 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 850.51it/s]

# %%
model = node2vec_testgraph.fit(window=10,min_count=1,batch_words=4)
model.save(u'node2vec_test.model')
model.wv.save_word2vec_format(u'vectors_for_nodes')

# %%
model2 = model.wv.load_word2vec_format('vectors_for_nodes')

# %%
model2['1']
# Out:
# array([ 0.03514302,  0.00965654,  0.00197433,  0.04982345, -0.01735988,
#         0.04201948,  0.0409997 ,  0.01276197, -0.03726938,  0.04504183],
#       dtype=float32)

# %%
'''
node2vec模块在整个实验中的作用：用于给提取得到的subgraph进行embedding的处理
处理得到关于subgraph中所有节点的vector
之后计算相似度
'''
